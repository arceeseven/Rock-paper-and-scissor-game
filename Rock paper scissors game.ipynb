# %%
import random

rnd = 0
comp_point= 0
point = 0

def cho():
    if choice == 1:
        print("You choose rock")
    if choice == 2:
        print("You choose paper")
    if choice == 3:
        print("You choose scissor")

print("Welcome to the rock, paper, scissors game! \n")
play = int(input("How many rounds do you to play?: "))
print("Below are the choices you have to choose from:")
print("1. Rock \n2. Paper \n3. Scissor \n")

while rnd != play:
    try:
        choice = int(input("Choose a number above that corresponds to your choice: "))
        cho()
    
        computer = random.randint(0, 2)
        a = ['rock', 'paper', 'scissors']
        print("The computer is:" , a[computer])
        choice -= 1
        rnd += 1
                 
        if choice == 0: #rock
            if computer == 0:
                print("Tie")
            if computer == 1:
                print("You lose")
                comp_point += 1
            if computer == 2:
                print("You win!")
                point += 1
        if choice == 1: #paper
            if computer == 0:
                print("You win!")
                point += 1
            if computer == 1:
                print("Tie")
            if computer == 2:
                print("You lose")
                comp_point += 1
        if choice == 2: #scissor
            if computer == 0:
                print("You lose")
                comp_point += 1
            if computer == 1:
                print("You win!")
                point += 1
            if computer == 2:
                print("Tie")     
        print("")

    except ValueError or 1 < input > 3:
        print("Invalid input")
        
print(f"SCORE: \nPlayer: {point}  Computer: {comp_point}")
# Out:
# Welcome to the rock, paper, scissors game!
#
# How many rounds do you to play?: 5
# Below are the choices you have to choose from:
# 1. Rock
# 2. Paper
# 3. Scissor
#
# Choose a number above that corresponds to your choice: 4
# Invalid choice
# The computer is: paper
#
# Choose a number above that corresponds to your choice: 2
# You choose paper
# Invalid choice
# The computer is: rock
# You win!
#
# Choose a number above that corresponds to your choice: 3
# You choose scissor
# The computer is: scissors
# Tie
#
# Choose a number above that corresponds to your choice: 1
# You choose rock
# Invalid choice
# The computer is: rock
# Tie
#
# Choose a number above that corresponds to your choice: 2
# You choose paper
# Invalid choice
# The computer is: scissors
# You lose
#
# SCORE:
# Player: 1  Computer: 1

# %% [markdown]
# ##
